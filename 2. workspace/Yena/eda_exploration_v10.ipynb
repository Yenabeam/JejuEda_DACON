# %% [markdown]
# # 전체 데이터 작업

# %%
pd.options.display.float_format = '{:.5f}'.format

# %%
# # 피클 저장하기 

# with open('jeju_all.pickle','wb') as fw:
#     pickle.dump(jeju_all, fw)

# %%
import pickle
with open('jeju_all.pickle','rb') as fr:
    jeju_all = pickle.load(fr)

jeju_all
# Out:
#         OBJECTID  Field1      YM     SIDO SIGUNGU FranClass       Type Time  \
# 0              1       1  202005  제주특별자치도     제주시        영세       일반한식  00시
# 1           4904    4904  202005  제주특별자치도     제주시        영세       일반한식  01시
# 2           8569    8569  202005  제주특별자치도     제주시        영세       일반한식  02시
# 3          11270   11270  202005  제주특별자치도     제주시        영세       일반한식  03시
# 4          19122   19122  202005  제주특별자치도     제주시        중소        한의원  07시
# ...          ...     ...     ...      ...     ...       ...        ...  ...
# 280080    275532  275532  202008  제주특별자치도     제주시        영세       보습학원   x시
# 280081    275664  275664  202008  제주특별자치도     제주시        영세  학원(회원제형태)   x시
# 280082    278935  278935  202008  제주특별자치도    서귀포시        영세      예체능학원   x시
# 280083    279538  279538  202008  제주특별자치도    서귀포시        영세       기타가구   x시
# 280084    279785  279785  202008  제주특별자치도     제주시        영세      기타숙박업   x시
#
#         TotalSpent  DisSpent  NumofSpent  NumofDisSpent      POINT_X  \
# 0           363000     66500          10              2 877005.98340
# 1            86500         0           3              0 877005.98340
# 2           208000         0           5              0 877005.98340
# 3            18000         0           1              0 877005.98340
# 4             4800         0           2              0 877005.98340
# ...            ...       ...         ...            ...          ...
# 280080      200000         0           1              0 910239.73420
# 280081      220000         0           1              0 910390.62740
# 280082      110000         0           1              0 921003.98200
# 280083       50000         0           1              0 937500.16740
# 280084       17470         0           2              0 941114.05310
#
#              POINT_Y                 lon                lat  \
# 0      1479766.07300  126.17889362710162  33.30231529076243
# 1      1479766.07300  126.17889362710162  33.30231529076243
# 2      1479766.07300  126.17889362710162  33.30231529076243
# 3      1479766.07300  126.17889362710162  33.30231529076243
# 4      1479766.07300  126.17889362710162  33.30231529076243
# ...              ...                 ...                ...
# 280080 1500965.97360  126.53369851534627  33.49678916515772
# 280081 1500766.78250    126.535342658025   33.4950054416331
# 280082 1476177.84050  126.65174159048293  33.27407883370635
# 280083 1486052.75280  126.82818252032293  33.36422597166203
# 280084 1503713.22230  126.86586853032782  33.52371304945294
#
#                                      lon_lat  dong Category
# 0       126.17889362710162_33.30231529076243   한경면    외식/주점
# 1       126.17889362710162_33.30231529076243   한경면    외식/주점
# 2       126.17889362710162_33.30231529076243   한경면    외식/주점
# 3       126.17889362710162_33.30231529076243   한경면    외식/주점
# 4       126.17889362710162_33.30231529076243   한경면       의료
# ...                                      ...   ...      ...
# 280080  126.53369851534627_33.49678916515772  이도이동    교육/육아
# 280081     126.535342658025_33.4950054416331  이도이동    교육/육아
# 280082  126.65174159048293_33.27407883370635   남원읍    교육/육아
# 280083  126.82818252032293_33.36422597166203   성산읍    생활/기타
# 280084  126.86586853032782_33.52371304945294   구좌읍    여행/숙박
#
# [1119429 rows x 19 columns]

# %% [markdown]
# # 1. 어떤 지역에서 재난 지원금이 많이 쓰였는지
# # - 읍면동 그룹 > 재난지원금 금액의 합계
# # - 상위 읍면동 5곳 확인

# %%
jeju_all

# 재난지원금 지역별 총 합계 확인 
jeju_all_dispent = jeju_all.groupby('dong').sum().sort_values('DisSpent', ascending = False)
jeju_all_dispent.reset_index(inplace=True)
jeju_all_dispent['dong'].unique()
# Out:
# array(['노형동', '연동', '이도이동', '일도이동', '서귀동', '애월읍', '일도일동', '도남동', '동홍동',
#        '한림읍', '대정읍', '아라일동', '화북일동', '조천읍', '외도일동', '성산읍', '삼도일동', '이도일동',
#        '남원읍', '표선면', '삼도이동', '건입동', '도련일동', '중문동', '용담이동', '토평동', '강정동',
#        '아라이동', '안덕면', '구좌읍', '용담일동', '오라이동', '상효동', '한경면', '삼양이동', '서호동',
#        '서홍동', '오라삼동', '오라일동', '법환동', '화북이동', '봉개동', '도두일동', '색달동', '추자면',
#        '이호이동', '하효동', '해안동', '용담삼동', '호근동', '내도동', '오등동', '대포동', '보목동',
#        '삼양일동', '영평동', '이호일동', '상예동', '도평동', '도련이동', '신효동', '월평동', '도두이동',
#        '외도이동', '하원동', '우도면', '회천동', '도순동', '회수동', '하예동', '삼양삼동', '용강동',
#        '영남동'], dtype=object)

# %%
from matplotlib import font_manager, rc
import matplotlib.pyplot as plt
plt.rcParams['axes.unicode_minus'] = False
f_path= "C:/Windows/Fonts/malgun.ttf"
font_name= font_manager.FontProperties(fname=f_path).get_name()
rc('font', family =font_name)
plt.rc('font', family='Malgun Gothic')
from matplotlib import rc
import seaborn as sns

# %%
# 상위 10개 지역 barplot 표현 
dispent_bottom = jeju_all_dispent[:10]

plt.figure(figsize=(10,4))
sns.barplot(x='DisSpent', y='dong', data= jeju_all_dispent[:10], palette='Blues_d')

########## 제주 중심지역 위주로 재난지원금이 사용됨 #########

# %%
# 하위 지역 10곳 
dispent_bottom = jeju_all_dispent[:62:-1]

plt.figure(figsize=(10,4))
sns.barplot(x='DisSpent', y='dong', data= jeju_all_dispent[:62:-1], palette='Blues')

# %%
#folium top10 시각화 
# import folium 
# map = folium.Map(location = [33.38773221915759,126.54124720118492], zoom_start=10)

# for item in dispent_bottom.index


#업체 시각화

# %% [markdown]
# # 어떤 지역에서의 인당 재난지원금 사용 비중이 높았는지
# - 재난 지원금 사용금액은 1인가구일수록 높은 경향
# - 제주도 1인 가구 지역과의 관계
# - 경향이 다르다면 지역민은 다른 곳에 가서 소비했을 것임

# %%
ppl = pd.read_csv('./jeju_ppl.csv')
ppl.head()
# Out:
#   dong    ppl
# 0  한림읍  24747
# 1  애월읍  37847
# 2  구좌읍  16118
# 3  조천읍  25742
# 4  한경면   9488

# %%
# 데이터 합치기 (동별 사용금액 합계, 인구수)

jeju_all_2 = pd.merge(jeju_all_dispent,ppl,on='dong')
jeju_all_2.head()
# Out:
#    dong     OBJECTID       Field1           YM   TotalSpent    DisSpent  \
# 0   노형동  13132052420  13132052420  18860741288  60306072018  3600581774
# 1    연동  13086905746  13086905746  19224958431  66132634501  2655454860
# 2  이도이동  11613906917  11613906917  16148803115  42412956256  2485420890
# 3  일도이동   5773201493   5773201493   8072583552  24009935766  2138328922
# 4   애월읍   6409590458   6409590458   9663588290  30586306203  1405507481
#
#    NumofSpent  NumofDisSpent           POINT_X            POINT_Y    ppl
# 0     1999363         127628 84503233243.14549 140009302519.20633  56746
# 1     1933800          95686 86252129801.84601 142739675795.30222  43756
# 2     1488964          88475 72782431925.90149 119982610107.20915  50746
# 3      768619          62619 36399896508.15907  60025218406.66868  33548
# 4      977019          45583 42829318151.84782  71627459076.61865  37847

# %%
jeju_all_2['DisSpent_person'] = jeju_all_2['DisSpent'] / jeju_all_2['ppl']
jeju_all_2.sort_values(by= 'DisSpent_person', ascending = False,inplace = True)
jeju_all_2.head(10)
# Out:
#     dong     OBJECTID       Field1           YM   TotalSpent    DisSpent  \
# 5   일도일동   2940290222   2940290222   4074470896  13463172598  1337076048
# 12  이도일동   3157337145   3157337145   4677056250  10734320739   699832176
# 15  삼도이동   2302976133   2302976133   3337349554  17163600191   585625283
# 3   일도이동   5773201493   5773201493   8072583552  24009935766  2138328922
# 0    노형동  13132052420  13132052420  18860741288  60306072018  3600581774
# 1     연동  13086905746  13086905746  19224958431  66132634501  2655454860
# 25   추자면    343443601    343443601    534509220    866954919   118628570
# 16   건입동   1665214940   1665214940   2527909498   9562572534   536581759
# 11  삼도일동   2814634547   2814634547   4140123143   9671961045   727364040
# 2   이도이동  11613906917  11613906917  16148803115  42412956256  2485420890
#
#     NumofSpent  NumofDisSpent           POINT_X            POINT_Y    ppl  \
# 5       338711          25578 18346340078.98769  30311400293.78540   2719
# 12      346481          23294 21059582850.92886  34777742638.96059   7775
# 15      449633          19392 15019918844.59014  24824935721.80586   8327
# 3       768619          62619 36399896508.15907  60025218406.66868  33548
# 0      1999363         127628 84503233243.14549 140009302519.20633  56746
# 1      1933800          95686 86252129801.84601 142739675795.30222  43756
# 25       27367           3488  2352751166.69019   4107925537.78026   1958
# 16      288100          16711 11391346769.04460  18809749608.89783   9356
# 11      342952          27911 18628873048.72687  30773350242.50340  13797
# 2      1488964          88475 72782431925.90149 119982610107.20915  50746
#
#     DisSpent_person
# 5      491752.86797
# 12      90010.56926
# 15      70328.48361
# 3       63739.38601
# 0       63450.84718
# 1       60687.78819
# 25      60586.60368
# 16      57351.62024
# 11      52718.99978
# 2       48977.67095

# %%
# 지역별 재난 지원금 top 사용 업종 
# 지역별 재난 지원금 비중 top 사용 업종

# %%
jeju_all['dis/tot'] = round(jeju_all['DisSpent'] / jeju_all['TotalSpent'],1)
jeju_all['count'] = 1 
jeju_all.head()
# Out:
#    OBJECTID  Field1      YM     SIDO SIGUNGU FranClass  Type Time  TotalSpent  \
# 0         1       1  202005  제주특별자치도     제주시        영세  일반한식  00시      363000
# 1      4904    4904  202005  제주특별자치도     제주시        영세  일반한식  01시       86500
# 2      8569    8569  202005  제주특별자치도     제주시        영세  일반한식  02시      208000
# 3     11270   11270  202005  제주특별자치도     제주시        영세  일반한식  03시       18000
# 4     19122   19122  202005  제주특별자치도     제주시        중소   한의원  07시        4800
#
#    DisSpent  ...  NumofDisSpent      POINT_X       POINT_Y  \
# 0     66500  ...              2 877005.98340 1479766.07300
# 1         0  ...              0 877005.98340 1479766.07300
# 2         0  ...              0 877005.98340 1479766.07300
# 3         0  ...              0 877005.98340 1479766.07300
# 4         0  ...              0 877005.98340 1479766.07300
#
#                   lon                lat  \
# 0  126.17889362710162  33.30231529076243
# 1  126.17889362710162  33.30231529076243
# 2  126.17889362710162  33.30231529076243
# 3  126.17889362710162  33.30231529076243
# 4  126.17889362710162  33.30231529076243
#
#                                 lon_lat dong Category dis/tot  count
# 0  126.17889362710162_33.30231529076243  한경면    외식/주점 0.20000      1
# 1  126.17889362710162_33.30231529076243  한경면    외식/주점 0.00000      1
# 2  126.17889362710162_33.30231529076243  한경면    외식/주점 0.00000      1
# 3  126.17889362710162_33.30231529076243  한경면    외식/주점 0.00000      1
# 4  126.17889362710162_33.30231529076243  한경면       의료 0.00000      1
#
# [5 rows x 21 columns]

# %%
# 조천읍 

cond1 = jeju_all['SIGUNGU'] == '제주시'
cond2 = jeju_all['dong'].str.contains('조천읍')
df_reg_jce = jeju_all[cond1&cond2]

df_reg_jce_ty = df_reg_jce.groupby(['Type']).sum().sort_values('dis/tot', ascending=False)
df_reg_jce_ty = df_reg_jce_ty.reset_index()
df_reg_jce_ty.head()

plt.figure(figsize=(18,3))
sns.barplot(x= 'Type',y='dis/tot', data= df_reg_jce_ty[:10])

# %%
# 제주시 

cond1 = jeju_all['SIGUNGU'] == '제주시'
cond2 = jeju_all['dong'].str.contains('동')
df_reg_jejusi = jeju_all[cond1&cond2]

df_reg_jejusi_ty = df_reg_jejusi.groupby(['Type']).sum().sort_values('dis/tot', ascending=False)
df_reg_jejusi_ty = df_reg_jejusi_ty.reset_index()
df_reg_jejusi_ty.head()

plt.figure(figsize=(18,3))
sns.barplot(x= 'Type',y='dis/tot', data= df_reg_jejusi_ty[:10])

# %%
# 구좌읍

cond1 = jeju_all['SIGUNGU'] == '제주시'
cond2 = jeju_all['dong'].str.contains('구좌읍')
df_reg_gj = jeju_all[cond1&cond2]

df_reg_gj_ty = df_reg_gj.groupby(['Type']).sum().sort_values('dis/tot', ascending=False)
df_reg_gj_ty = df_reg_gj_ty.reset_index()
df_reg_gj_ty.head()

plt.figure(figsize=(18,3))
sns.barplot(x= 'Type',y='dis/tot', data= df_reg_gj_ty[:10])

# %%
plt.figure(figsize=(18,2)) 
sns.barplot(x= 'Type',y='dis/tot', data= df_reg_jce_ty[:10])

# plt.figure(figsize=(18,2)) #하위 
# sns.barplot(x= 'Type',y='dis/tot', data= df_reg_jce_ty[85:93])

plt.figure(figsize=(18,2))
sns.barplot(x= 'Type',y='dis/tot', data= df_reg_jejusi_ty[:10])

plt.figure(figsize=(18,2))
sns.barplot(x= 'Type',y='dis/tot', data= df_reg_gj_ty[:10])
#조천읍/제주시/구좌읍

# %%
# 어떤 업종에서 재난 지원금 총사용량이 높은지
# 어떤 업종에서 재난 지원금이 사용 비중이 높은지 
# 어떤 업종에서 재난 지원금 사용 비중이 낮은지

# %% [markdown]
# # '########################################'

# %%
jeju_all.head()
# Out:
#    OBJECTID  Field1      YM     SIDO SIGUNGU FranClass  Type Time  TotalSpent  \
# 0         1       1  202005  제주특별자치도     제주시        영세  일반한식  00시      363000
# 1      4904    4904  202005  제주특별자치도     제주시        영세  일반한식  01시       86500
# 2      8569    8569  202005  제주특별자치도     제주시        영세  일반한식  02시      208000
# 3     11270   11270  202005  제주특별자치도     제주시        영세  일반한식  03시       18000
# 4     19122   19122  202005  제주특별자치도     제주시        중소   한의원  07시        4800
#
#    DisSpent  NumofSpent  NumofDisSpent      POINT_X       POINT_Y  \
# 0     66500          10              2 877005.98340 1479766.07300
# 1         0           3              0 877005.98340 1479766.07300
# 2         0           5              0 877005.98340 1479766.07300
# 3         0           1              0 877005.98340 1479766.07300
# 4         0           2              0 877005.98340 1479766.07300
#
#                   lon                lat  \
# 0  126.17889362710162  33.30231529076243
# 1  126.17889362710162  33.30231529076243
# 2  126.17889362710162  33.30231529076243
# 3  126.17889362710162  33.30231529076243
# 4  126.17889362710162  33.30231529076243
#
#                                 lon_lat dong Category
# 0  126.17889362710162_33.30231529076243  한경면    외식/주점
# 1  126.17889362710162_33.30231529076243  한경면    외식/주점
# 2  126.17889362710162_33.30231529076243  한경면    외식/주점
# 3  126.17889362710162_33.30231529076243  한경면    외식/주점
# 4  126.17889362710162_33.30231529076243  한경면       의료

# %%
# 총사용금액으로 정리해보기

figure, ((ax1,ax2), (ax3,ax4),(ax5,ax6)) = plt.subplots(nrows=3, ncols=2)
figure.set_size_inches(18,8)

sns.barplot(data=jeju_all, x="YM", y="TotalSpent", ax=ax1)
sns.barplot(data=jeju_all, x="Time", y="TotalSpent", ax=ax2)
sns.barplot(data=jeju_all, x="SIGUNGU", y="TotalSpent", ax=ax3)
sns.barplot(data=jeju_all, x="dong", y="TotalSpent", ax=ax4)
sns.barplot(data=jeju_all, x="Type", y="TotalSpent", ax=ax5)
sns.barplot(data=jeju_all, x="Category", y="TotalSpent", ax=ax6)

# %%
# 월별 사용금액 / 재난지원금 

figure, (ax1,ax2) = plt.subplots(nrows=1, ncols=2)
figure.set_size_inches(18,5)


sns.barplot(data=jeju_all, x="YM", y="TotalSpent", ax=ax1)
sns.barplot(data=jeju_all, x="YM", y="DisSpent", ax=ax2)

# %%
f, ax = plt.subplots(figsize=(8,4))
sns.barplot(x='YM', y ='TotalSpent', data=jeju_all, color='#b3cde3')
sns.barplot(x='YM', y ='DisSpent', data=jeju_all, color='#fbb4ae')

# %%
# 5월 8월의 업종별 사용금액 (상위 / 하위)

# 5월 8월 데이터 분리하기 
cond1 = jeju_all['YM'] == 202005
cond2 = jeju_all['YM'] == 202008
jeju_may_aug = jeju_all[cond1|cond2]

jeju_may_aug.head()
# Out:
#    OBJECTID  Field1      YM     SIDO SIGUNGU FranClass  Type Time  TotalSpent  \
# 0         1       1  202005  제주특별자치도     제주시        영세  일반한식  00시      363000
# 1      4904    4904  202005  제주특별자치도     제주시        영세  일반한식  01시       86500
# 2      8569    8569  202005  제주특별자치도     제주시        영세  일반한식  02시      208000
# 3     11270   11270  202005  제주특별자치도     제주시        영세  일반한식  03시       18000
# 4     19122   19122  202005  제주특별자치도     제주시        중소   한의원  07시        4800
#
#    DisSpent  NumofSpent  NumofDisSpent      POINT_X       POINT_Y  \
# 0     66500          10              2 877005.98340 1479766.07300
# 1         0           3              0 877005.98340 1479766.07300
# 2         0           5              0 877005.98340 1479766.07300
# 3         0           1              0 877005.98340 1479766.07300
# 4         0           2              0 877005.98340 1479766.07300
#
#                   lon                lat  \
# 0  126.17889362710162  33.30231529076243
# 1  126.17889362710162  33.30231529076243
# 2  126.17889362710162  33.30231529076243
# 3  126.17889362710162  33.30231529076243
# 4  126.17889362710162  33.30231529076243
#
#                                 lon_lat dong Category
# 0  126.17889362710162_33.30231529076243  한경면    외식/주점
# 1  126.17889362710162_33.30231529076243  한경면    외식/주점
# 2  126.17889362710162_33.30231529076243  한경면    외식/주점
# 3  126.17889362710162_33.30231529076243  한경면    외식/주점
# 4  126.17889362710162_33.30231529076243  한경면       의료

# %%
f, ax = plt.subplots(figsize=(20,4))
sns.barplot(x='Category', y ='TotalSpent', data=jeju_may_aug, hue='YM')

# %%
# 의료, 레저/스포츠, 교육/육아, 쇼핑/패션 분야가 재난지원금이 없는 8월 대비 높음 
# 재난지원금으로 소비 촉진이 일어난 지역

# %%
# 제주시 --동 > 제주시로 통일 / 

cond1 = jeju_all['SIGUNGU'] == '제주시'
cond2 = jeju_all['dong'].str.contains('동')
jeju_all['dong_cat'] = np.where(jeju_all['dong'].str.contains('동'),jeju_all['SIGUNGU'], jeju_all['dong'])

jeju_all.head()
# Out:
#    OBJECTID  Field1      YM     SIDO SIGUNGU FranClass  Type Time  TotalSpent  \
# 0         1       1  202005  제주특별자치도     제주시        영세  일반한식  00시      363000
# 1      4904    4904  202005  제주특별자치도     제주시        영세  일반한식  01시       86500
# 2      8569    8569  202005  제주특별자치도     제주시        영세  일반한식  02시      208000
# 3     11270   11270  202005  제주특별자치도     제주시        영세  일반한식  03시       18000
# 4     19122   19122  202005  제주특별자치도     제주시        중소   한의원  07시        4800
#
#    DisSpent  NumofSpent  NumofDisSpent      POINT_X       POINT_Y  \
# 0     66500          10              2 877005.98340 1479766.07300
# 1         0           3              0 877005.98340 1479766.07300
# 2         0           5              0 877005.98340 1479766.07300
# 3         0           1              0 877005.98340 1479766.07300
# 4         0           2              0 877005.98340 1479766.07300
#
#                   lon                lat  \
# 0  126.17889362710162  33.30231529076243
# 1  126.17889362710162  33.30231529076243
# 2  126.17889362710162  33.30231529076243
# 3  126.17889362710162  33.30231529076243
# 4  126.17889362710162  33.30231529076243
#
#                                 lon_lat dong Category dong_cat
# 0  126.17889362710162_33.30231529076243  한경면    외식/주점      한경면
# 1  126.17889362710162_33.30231529076243  한경면    외식/주점      한경면
# 2  126.17889362710162_33.30231529076243  한경면    외식/주점      한경면
# 3  126.17889362710162_33.30231529076243  한경면    외식/주점      한경면
# 4  126.17889362710162_33.30231529076243  한경면       의료      한경면

# %%
# 재난지원금 어디 지역에 도움이 되었는지 
f, ax = plt.subplots(figsize=(20,4))
sns.barplot(x='dong_cat', y ='TotalSpent', data=jeju_all, hue='YM')

# %%
###### 제주시와 추자면의 경우 5월과 8월의 사용금액이 거의 비슷함 
- 제주시 : 대부분의 상점이 몰려있음 
- 추자면 : 제주도와 떨어진 외딴 섬으로 해당 지역 외의 소비가 물리적으로 어려움

# %%
f, ax = plt.subplots(figsize=(20,4))
sns.barplot(x='SIGUNGU', y ='TotalSpent', data=jeju_may_aug, hue='YM')

#제주시가 서귀포시에 비해 재난지원금의 상대적 효과가 큼

# %%
# 재난지원금 어느 상업규모에 도움이 되었는지 
f, ax = plt.subplots(figsize=(20,4))
sns.barplot(x='FranClass', y ='TotalSpent', data=jeju_all, hue='YM')

# %%
f, ax = plt.subplots(figsize=(4,4))
sns.barplot(x='YM', y ='TotalSpent', data=jeju_all[jeju_all['FranClass']=='영세'])

# %%
# 재난지원금 어느 상업규모에 도움이 되었는지 

figure,((ax1,ax2), (ax3,ax4),(ax5)) = plt.subplots(nrows=3, ncols=2)
figure.set_size_inches(18,5)

sns.barplot(x='YM', y ='TotalSpent', data=jeju_all[jeju_all['FranClass']=='영세'],ax=ax1)
sns.barplot(x='YM', y ='TotalSpent', data=jeju_all[jeju_all['FranClass']=='중소'], ax=ax2)
sns.barplot(x='YM', y ='TotalSpent', data=jeju_all[jeju_all['FranClass']=='중소1'], ax=ax3)
sns.barplot(x='YM', y ='TotalSpent', data=jeju_all[jeju_all['FranClass']=='일반'], ax=ax4)
sns.barplot(x='YM', y ='TotalSpent', data=jeju_all[jeju_all['FranClass']=='중소2'], ax=ax5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-f42092485c13> in <module>
#       8 sns.barplot(x='YM', y ='TotalSpent', data=jeju_all[jeju_all['FranClass']=='중소1'], ax=ax3)
#       9 sns.barplot(x='YM', y ='TotalSpent', data=jeju_all[jeju_all['FranClass']=='일반'], ax=ax4)
# ---> 10 sns.barplot(x='YM', y ='TotalSpent', data=jeju_all[jeju_all['FranClass']=='중소2'], ax=ax5)
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3150         ax = plt.gca()
#    3151
# -> 3152     plotter.plot(ax, kwargs)
#    3153     return ax
#    3154
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in plot(self, ax, bar_kws)
#    1655     def plot(self, ax, bar_kws):
#    1656         """Make the plot."""
# -> 1657         self.draw_bars(ax, bar_kws)
#    1658         self.annotate_axes(ax)
#    1659         if self.orient == "h":
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in draw_bars(self, ax, kws)
#    1614         """Draw the bars onto `ax`."""
#    1615         # Get the right matplotlib function depending on the orientation
# -> 1616         barfunc = ax.bar if self.orient == "v" else ax.barh
#    1617         barpos = np.arange(len(self.statistic))
#    1618
#
# AttributeError: 'numpy.ndarray' object has no attribute 'bar'
