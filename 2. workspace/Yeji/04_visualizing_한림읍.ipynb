# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pickle
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

from matplotlib import font_manager
f_path = "C:\Windows\Fonts\malgun.ttf"
font_manager.FontProperties(fname=f_path).get_name()
from matplotlib import rc
rc('font', family='Malgun Gothic')

# %%
## 1. 전체 데이터, pickle 데이터 불러오기

# %%
jeju = pd.read_csv('./datas/jeju_full.csv')
jeju.drop(columns=['Unnamed: 0'], inplace=True)

# %%
with open('./datas/jeju_uniq_data5.pickle', 'rb') as f:
    may = pickle.load(f)

# %%
hanlim_5 = may[may['dong'].isin(['한림읍'])]

# %%
with open('./datas/jeju_uniq_data6.pickle', 'rb') as f:
    june = pickle.load(f)

# %%
hanlim_6 = june[june['dong'].isin(['한림읍'])]

# %%
with open('./datas/jeju_uniq_data7.pickle', 'rb') as f:
    july = pickle.load(f)

# %%
hanlim_7 = july[july['dong'].isin(['한림읍'])]

# %%
with open('./datas/jeju_uniq_data8.pickle', 'rb') as f:
    august = pickle.load(f)

# %%
hanlim_8 = august[august['dong'].isin(['한림읍'])]

# %%
## 5, 6, 7, 8월 pickle 데이터 'hanlim'에 합치고 'X', 'Y' 컬럼 드랍

# %%
frames = [hanlim_5, hanlim_6, hanlim_7, hanlim_8]
hanlim = pd.concat(frames, axis=0)
hanlim.drop(columns=['X', 'Y'], inplace=True)

# %%
##'jeju' Type replace 해서 'hanlim' 데이터에 넣기

# %%
hanlim.replace(dict.fromkeys(['택시', '기타교통수단', '통신기기'], '교통/통신'), inplace=True)
hanlim.replace(dict.fromkeys(['대형할인점', '농축협직영매장', '농협하나로클럽', '편의점', '슈퍼마켓', '정육점', '기타유통업', '연쇄점', '상품권', '인삼제품', '홍삼제품', '농축수산품', '주류판매점', '기타건강식', '건강식품(회원제형태)'], '마트/편의점(유통)'), inplace=True)
hanlim.replace(dict.fromkeys(['악기점', 'DVD음반테이프판매', '문화취미기타', '영화관', '티켓', '수족관', '화랑'], '영화/문화'), inplace=True)
hanlim.replace(dict.fromkeys(['내의판매점', '양품점', '옷감직물', '귀금속', '기타직물', '스포츠의류', '가방', '정장', '악세사리', '기타잡화', '신발', '기타의류', '단체복', '아동의류', '캐쥬얼의류', '맞춤복점', '제화점', '인터넷Mall', '인터넷종합Mall'], '쇼핑/패션'), inplace=True)
hanlim.replace(dict.fromkeys(['제과점', '스넥', '기타음료식품'], '카페/베이커리'), inplace=True)
hanlim.replace(dict.fromkeys(['미용재료', '화장품', '피부미용실', '미용원', '이용원'], '뷰티'), inplace=True)
hanlim.replace(dict.fromkeys(['구내매점', '단란주점', '주점', '서양음식', '일반한식', '일식회집', '중국음식',  '유흥주점', '칵테일바'], '외식/주점'), inplace=True)
hanlim.replace(dict.fromkeys(['세탁소', '애완동물', '화원', '침구수예점', '성인용품점', '가전제품', '기타가구', '조명기구', '민예공예품', '주방용식기', '기타전기제품', '소프트웨어', '주방용구', '카페트커텐천막', '컴퓨터', '카메라', '일반가구', '정수기', '철제가구', '시계', '안경', '사우나', '안마스포츠마사지', '사진관', '인테리어', 'CATV'], '생활/기타'), inplace=True)
hanlim.replace(dict.fromkeys(['완구점', '화방표구점', '문구용품', '일반서적', '출판인쇄물', '기타사무용', '사무기기', '전문서적', '정기간행물', '기타서적문구', '서적출판(회원제형태)'], '서점/문구'), inplace=True)
hanlim.replace(dict.fromkeys(['기타보험', '손해보험'], '금융'), inplace=True)
hanlim.replace(dict.fromkeys(['기념품점', '기타숙박업', '특급호텔', '2급호텔', '1급호텔', '콘도', '렌트카', '관광여행', '항공사', '여객선', '면세점'], '여행/숙박'), inplace=True)
hanlim.replace(dict.fromkeys(['레져용품수리', '스포츠레져용품', '골프용품', '노래방', '당구장', '골프경기장', '볼링장', '골프연습장', '헬스크럽', '레져업소(회원제형태)', '기타레져업', '종합레져타운', '수영장', '테니스장', '기타회원제형태업소', ], '레저/스포츠'), inplace=True)
hanlim.replace(dict.fromkeys(['유아원', '독서실', '보습학원', '기능학원', '기타교육', '외국어학원', '학원(회원제형태)', '예체능학원', '컴퓨터학원', '대학등록금', '학습지교육', '초중고교육기관'], '교육/육아'), inplace=True)
hanlim.replace(dict.fromkeys(['주유소', '자동차정비', 'LPG', '세차장', '유류판매', '이륜차판매', '윤활유전문판매', '자동차시트타이어', '중고자동차', '수입자동차', '자동차부품', '주차장', '기타자동차서비스', '카인테리어', ], '주유/자동차'), inplace=True)
hanlim.replace(dict.fromkeys(['약국', '종합병원', '기타의료기관및기기', '한약방', '제약회사', '의료용품', '건강진단', '한의원', '동물병원', '의원', '치과의원', '병원', '산후조리원', '치과병원'], '의료'), inplace=True)
hanlim.replace(dict.fromkeys(['목재석재철물', '건축요업품', '골동품점', '기계공구', '기타건축자재', '보일러펌프', '페인트', '냉열기기', '유리', '과학기자재', '기타광학품', '기타연료', '중장비수리', ], '건설/제조'), inplace=True)
hanlim.replace(dict.fromkeys(['기타농업관련', '비료농약사료종자', '농기계', '미곡상'], '농업'), inplace=True)
hanlim.replace(dict.fromkeys(['사무서비스', '기타대인서비스', '화물운송', '보관창고업', '종합용역', '조세서비스', '가례서비스', '공공요금', '위탁급식업', '기타용역서비스', '기타수리서비스', '기타운송', '가정용품수리', '견인서비스', '부동산중개임대', '부동산분양', '신변잡화수리', '사무통신기기수리', '법률회계서비스', '사무서비스(회원제형태)', '정보서비스', '기타업종', '기타비영리유통'], '서비스/기타'), inplace=True)

# %%
hanlim.tail()
# Out:
#         OBJECTID  Field1      YM     SIDO SIGUNGU FranClass   Type Time  \
# 279989    242126  242126  202008  제주특별자치도     제주시        일반  외식/주점  21시
# 279990    253957  253957  202008  제주특별자치도     제주시        일반  외식/주점  22시
# 279991    262896  262896  202008  제주특별자치도     제주시        일반  외식/주점  23시
# 280067    269676  269676  202008  제주특별자치도     제주시        영세  교육/육아   x시
# 280068    270027  270027  202008  제주특별자치도     제주시        영세  교육/육아   x시
#
#         TotalSpent  DisSpent  NumofSpent  NumofDisSpent      POINT_X  \
# 279989       12000         0           1              0  886282.6314
# 279990       40000         0           3              0  886282.6314
# 279991       20000         0           1              0  886282.6314
# 280067       44000         0           1              0  884694.4071
# 280068      240000         0           1              0  887877.0846
#
#              POINT_Y                 lon                lat  \
# ...

# %%
tot_hanlim = hanlim.groupby(['YM', 'Type'], as_index=False).sum()

# %% [markdown]
# ### 총 이용 금액, 지원금 이용 금액

# %%
# fig = plt.figure(figsize=(20,20))
# ax1 = fig.add_subplot(411)
# ax1 = sns.barplot(x='Type', y='TotalSpent', data=tot_hanlim[tot_hanlim['YM'] == 202005].sort_values(by='TotalSpent', ascending=False), palette='coolwarm')
# # ax1.set_xticks(fontsize=10, rotation=45)
# ax1.set_title('5월 업종별 총 이용금액 (TotalSpent)')

# ax2 = fig.add_subplot(412)
# ax2 = sns.barplot(x='Type', y='TotalSpent', data=tot_hanlim[tot_hanlim['YM'] == 202006].sort_values(by='TotalSpent', ascending=False), palette='coolwarm')
# # ax2.set_xticks(fontsize=10, rotation=45)
# ax2.set_title('6월 업종별 총 이용금액 (TotalSpent)')

# ax3 = fig.add_subplot(413)
# ax3 = sns.barplot(x='Type', y='TotalSpent', data=tot_hanlim[tot_hanlim['YM'] == 202007].sort_values(by='TotalSpent', ascending=False), palette='coolwarm')
# # ax3.set_xticks(fontsize=10, rotation=45)
# ax3.set_title('7월 업종별 총 이용금액 (TotalSpent)')

# ax4 = fig.add_subplot(414)
# ax4 = sns.barplot(x='Type', y='TotalSpent', data=tot_hanlim[tot_hanlim['YM'] == 202008].sort_values(by='TotalSpent', ascending=False), palette='coolwarm')
# # ax1.set_xticks(fontsize=10, rotation=45)
# ax4.set_title('8월 업종별 총 이용금액 (TotalSpent)')
# plt.show()

# %%
# fig = plt.figure(figsize=(20,20))
# ax1 = fig.add_subplot(411)
# ax1 = sns.barplot(x='Type', y='DisSpent', data=tot_hanlim[tot_hanlim['YM'] == 202005].sort_values(by='DisSpent', ascending=False), palette='coolwarm')
# # ax1.set_xticks(fontsize=10, rotation=45)
# ax1.set_title('5월 업종별 총 지원금 이용금액 (DisSpent)')

# ax2 = fig.add_subplot(412)
# ax2 = sns.barplot(x='Type', y='DisSpent', data=tot_hanlim[tot_hanlim['YM'] == 202006].sort_values(by='DisSpent', ascending=False), palette='coolwarm')
# # ax2.set_xticks(fontsize=10, rotation=45)
# ax2.set_title('6월 업종별 총 지원금 이용금액 (DisSpent)')

# ax3 = fig.add_subplot(413)
# ax3 = sns.barplot(x='Type', y='DisSpent', data=tot_hanlim[tot_hanlim['YM'] == 202007].sort_values(by='DisSpent', ascending=False), palette='coolwarm')
# # ax3.set_xticks(fontsize=10, rotation=45)
# ax3.set_title('7월 업종별 총 지원금 이용금액 (DisSpent)')

# ax4 = fig.add_subplot(414)
# ax4 = sns.barplot(x='Type', y='DisSpent', data=tot_hanlim[tot_hanlim['YM'] == 202008].sort_values(by='DisSpent', ascending=False), palette='coolwarm')
# # ax1.set_xticks(fontsize=10, rotation=45)
# ax4.set_title('8월 업종별 총 지원금 이용금액 (DisSpent)')
# plt.show()

# %%
# plt.figure(figsize=(10,6))
# sns.catplot(x='YM', y='TotalSpent', col='Type', data=tot_hanlim.sort_values(by='TotalSpent', ascending=False),
#             kind='bar', col_wrap=3, palette='coolwarm');

# %%
# plt.figure(figsize=(10,6))
# sns.catplot(x='YM', y='DisSpent', col='Type', data=tot_hanlim.sort_values(by='DisSpent', ascending=False),
#             kind='bar', col_wrap=3, palette='coolwarm');

# %%
tot_hanlim
# Out:
#         YM     Type   OBJECTID     Field1  TotalSpent  DisSpent  NumofSpent  \
# 0   202005    건설/제조   22365895   22365895   117677540  16066582        2011
# 1   202005    교육/육아   18800012   18800012   170930370   4364400        1589
# 2   202005    교통/통신    3672864    3672864     1158400     55000          48
# 3   202005       농업   13861165   13861165   192935012  29522440        1944
# 4   202005   레저/스포츠   49455082   49455082   413169599   7936341        5701
# ..     ...      ...        ...        ...         ...       ...         ...
# 63  202008    영화/문화    4847441    4847441    65277100     27000        2358
# 64  202008    외식/주점  655423808  655423808  2131982675   4003080       58587
# 65  202008       의료   40273680   40273680   133941860    725040        6295
# 66  202008   주유/자동차   33732914   33732914   431168957   1272562        9422
# 67  202008  카페/베이커리   87756865   87756865   189381060    276580       10347
#
#     NumofDisSpent       POINT_X       POINT_Y
# ...

# %% [markdown]
# ### 업종별 총 이용 건수, 지원금 이용 건수

# %%
## 'NumofSpent', 'NumofDisSpent' norm해서 barchart 겹쳐서 보기

# %%
col = ['NumofSpent', 'NumofDisSpent']
num_hanlim = tot_hanlim[col] / tot_hanlim[col].max()

# %%
norm_hanlim = tot_hanlim.copy()
norm_hanlim[col] = num_hanlim[col]
norm_hanlim
# Out:
#         YM     Type   OBJECTID     Field1  TotalSpent  DisSpent  NumofSpent  \
# 0   202005    건설/제조   22365895   22365895   117677540  16066582    0.025626
# 1   202005    교육/육아   18800012   18800012   170930370   4364400    0.020248
# 2   202005    교통/통신    3672864    3672864     1158400     55000    0.000612
# 3   202005       농업   13861165   13861165   192935012  29522440    0.024772
# 4   202005   레저/스포츠   49455082   49455082   413169599   7936341    0.072646
# ..     ...      ...        ...        ...         ...       ...         ...
# 63  202008    영화/문화    4847441    4847441    65277100     27000    0.030047
# 64  202008    외식/주점  655423808  655423808  2131982675   4003080    0.746559
# 65  202008       의료   40273680   40273680   133941860    725040    0.080216
# 66  202008   주유/자동차   33732914   33732914   431168957   1272562    0.120062
# 67  202008  카페/베이커리   87756865   87756865   189381060    276580    0.131849
#
#     NumofDisSpent       POINT_X       POINT_Y
# ...

# %%
norm_hanlim[norm_hanlim['YM'] == 202005].sort_values(by='NumofSpent', ascending=False)
# Out:
#         YM        Type   OBJECTID     Field1  TotalSpent   DisSpent  \
# 5   202005  마트/편의점(유통)  209986148  209986148  1320760847  253747504
# 13  202005       외식/주점  604527673  604527673  1567025387  157362836
# 16  202005     카페/베이커리   77981131   77981131   141219442   17655560
# 15  202005      주유/자동차   35205449   35205449   417799654   68860863
# 14  202005          의료   35973186   35973186   170236070   30272308
# 4   202005      레저/스포츠   49455082   49455082   413169599    7936341
# 10  202005       쇼핑/패션   43666177   43666177   136629790   20349240
# 7   202005       생활/기타   46712094   46712094    96119461   15176390
# 0   202005       건설/제조   22365895   22365895   117677540   16066582
# 3   202005          농업   13861165   13861165   192935012   29522440
# 12  202005       영화/문화    4552777    4552777    49363600    2444500
# 11  202005       여행/숙박   54588638   54588638    71772807    2622650
# 1   202005       교육/육아   18800012   18800012   170930370    4364400
# ...

# %%
fig = plt.figure(figsize=(20,20))
ax1 = fig.add_subplot(2, 2, 1)
ax1 = sns.set_color_codes('muted')
ax1 = sns.barplot(x='NumofDisSpent', y='Type', data=norm_hanlim[norm_hanlim['YM'] == 202005], label='Fund Spent', color='b')
ax1 = sns.set_color_codes('pastel')
ax1 = sns.barplot(x='NumofSpent', y='Type', data=norm_hanlim[norm_hanlim['YM'] == 202005], label='Total Spent', color='b')
ax1.legend(loc='best', frameon=True)
ax1.set_title('5월 업종별 총이용건수와 총 재난지원금 이용건수')

ax2 = fig.add_subplot(2, 2, 2)
ax2 = sns.set_color_codes('pastel')
ax2 = sns.barplot(x='NumofSpent', y='Type', data=norm_hanlim[norm_hanlim['YM'] == 202006], label='Total Spent', color='b')
ax2 = sns.set_color_codes('muted')
ax2 = sns.barplot(x='NumofDisSpent', y='Type', data=norm_hanlim[norm_hanlim['YM'] == 202006], label='Fund Spent', color='b')
ax2.legend(loc='best', frameon=True)
ax2.set_title('6월 업종별 총이용건수와 총 재난지원금 이용건수')

ax3 = fig.add_subplot(2, 2, 3)
ax3 = sns.set_color_codes('pastel')
ax3 = sns.barplot(x='NumofSpent', y='Type', data=norm_hanlim[norm_hanlim['YM'] == 202007], label='Total Spent', color='b')
ax3 = sns.set_color_codes('muted')
ax3 = sns.barplot(x='NumofDisSpent', y='Type', data=norm_hanlim[norm_hanlim['YM'] == 202007], label='Fund Spent', color='b')
ax3.legend(loc='best', frameon=True)
ax3.set_title('7월 업종별 총이용건수와 총 재난지원금 이용건수')

ax4 = fig.add_subplot(2, 2, 4)
ax4 = sns.set_color_codes('pastel')
ax4 = sns.barplot(x='NumofSpent', y='Type', data=norm_hanlim[norm_hanlim['YM'] == 202008], label='Total Spent', color='b')
ax4 = sns.set_color_codes('muted')
ax4 = sns.barplot(x='NumofDisSpent', y='Type', data=norm_hanlim[norm_hanlim['YM'] == 202008], label='Fund Spent', color='b')
ax4.legend(loc='best', frameon=True)
ax3.set_title('8월 업종별 총이용건수와 총 재난지원금 이용건수')
plt.show()

# %%
## norm 하지 않은 'NumofSpent', 'NumofDisSpent' barchart 따로 보기

# %%
fig = plt.figure(figsize=(20,20))
ax1 = fig.add_subplot(411)
ax1 = sns.barplot(x='Type', y='NumofSpent', data=tot_hanlim[tot_hanlim['YM'] == 202005].sort_values(by='NumofSpent', ascending=False), palette='coolwarm')
# ax1.set_xticks(fontsize=10, rotation=45)
ax1.set_title('5월 업종별 총 이용건수 (NumofSpent)')

ax2 = fig.add_subplot(412)
ax2 = sns.barplot(x='Type', y='NumofSpent', data=tot_hanlim[tot_hanlim['YM'] == 202006].sort_values(by='NumofSpent', ascending=False), palette='coolwarm')
# ax2.set_xticks(fontsize=10, rotation=45)
ax2.set_title('6월 업종별 총 이용건수 (NumofSpent)')

ax3 = fig.add_subplot(413)
ax3 = sns.barplot(x='Type', y='NumofSpent', data=tot_hanlim[tot_hanlim['YM'] == 202007].sort_values(by='NumofSpent', ascending=False), palette='coolwarm')
# ax3.set_xticks(fontsize=10, rotation=45)
ax3.set_title('7월 업종별 총 이용건수 (NumofSpent)')

ax4 = fig.add_subplot(414)
ax4 = sns.barplot(x='Type', y='NumofSpent', data=tot_hanlim[tot_hanlim['YM'] == 202008].sort_values(by='NumofSpent', ascending=False), palette='coolwarm')
# ax1.set_xticks(fontsize=10, rotation=45)
ax4.set_title('8월 업종별 총 이용건수 (NumofSpent)')
plt.show()

# %%
fig = plt.figure(figsize=(20,20))
ax1 = fig.add_subplot(411)
ax1 = sns.barplot(x='Type', y='NumofDisSpent', data=tot_hanlim[tot_hanlim['YM'] == 202005].sort_values(by='NumofDisSpent', ascending=False), palette='coolwarm')
# ax1.set_xticks(fontsize=10, rotation=45)
ax1.set_title('5월 업종별 총 지원금 이용건수 (NumofDisSpent)')

ax2 = fig.add_subplot(412)
ax2 = sns.barplot(x='Type', y='NumofDisSpent', data=tot_hanlim[tot_hanlim['YM'] == 202006].sort_values(by='NumofDisSpent', ascending=False), palette='coolwarm')
# ax2.set_xticks(fontsize=10, rotation=45)
ax2.set_title('6월 업종별 총 지원금 이용건수 (NumofDisSpent)')

ax3 = fig.add_subplot(413)
ax3 = sns.barplot(x='Type', y='NumofDisSpent', data=tot_hanlim[tot_hanlim['YM'] == 202007].sort_values(by='NumofDisSpent', ascending=False), palette='coolwarm')
# ax3.set_xticks(fontsize=10, rotation=45)
ax3.set_title('7월 업종별 총 지원금 이용건수 (NumofDisSpent)')

ax4 = fig.add_subplot(414)
ax4 = sns.barplot(x='Type', y='NumofDisSpent', data=tot_hanlim[tot_hanlim['YM'] == 202008].sort_values(by='NumofDisSpent', ascending=False), palette='coolwarm')
# ax1.set_xticks(fontsize=10, rotation=45)
ax4.set_title('8월 업종별 총 지원금 이용건수 (NumofDisSpent)')
plt.show()

# %% [markdown]
# ### 업종 시간대별 총 이용건수 추이

# %%
time_may_cat = hanlim[hanlim['YM'] == 202005].groupby(['Type', 'Time'], as_index=False).sum()
may_cat = hanlim[hanlim['YM'] == 202005].groupby(['Type'], as_index=False).sum()
may_cat = may_cat.sort_values(by='NumofSpent', ascending=False).head(10)
may_cat = [i for i in may_cat['Type']]
plot_may = time_may_cat[time_may_cat['Type'].isin((may_cat))]

time_jun_cat = hanlim[hanlim['YM'] == 202006].groupby(['Type', 'Time'], as_index=False).sum()
jun_cat = hanlim[hanlim['YM'] == 202006].groupby(['Type'], as_index=False).sum()
jun_cat = jun_cat.sort_values(by='NumofSpent', ascending=False).head(10)
jun_cat = [i for i in jun_cat['Type']]
plot_jun = time_jun_cat[time_jun_cat['Type'].isin((jun_cat))]

time_jul_cat = hanlim[hanlim['YM'] == 202007].groupby(['Type', 'Time'], as_index=False).sum()
jul_cat = hanlim[hanlim['YM'] == 202007].groupby(['Type'], as_index=False).sum()
jul_cat = jul_cat.sort_values(by='NumofSpent', ascending=False).head(10)
jul_cat = [i for i in jul_cat['Type']]
plot_jul = time_jul_cat[time_jul_cat['Type'].isin((jul_cat))]

time_aug_cat = hanlim[hanlim['YM'] == 202008].groupby(['Type', 'Time'], as_index=False).sum()
aug_cat = hanlim[hanlim['YM'] == 202008].groupby(['Type'], as_index=False).sum()
aug_cat = aug_cat.sort_values(by='NumofSpent', ascending=False).head(10)
aug_cat = [i for i in aug_cat['Type']]
plot_aug = time_aug_cat[time_aug_cat['Type'].isin((aug_cat))]

# %%
fig = plt.figure(figsize=(20,20))
ax1 = fig.add_subplot(221)
ax1 = sns.pointplot(x='Time', y='NumofSpent', hue='Type', data=plot_may)
ax1.set_title('5월 TOP10 업종 시간대별 총 이용건수')

ax2 = fig.add_subplot(222)
ax2 = sns.pointplot(x='Time', y='NumofSpent', hue='Type', data=plot_jun)
ax2.set_title('6월 TOP10 업종 시간대별 총 이용건수')

ax3 = fig.add_subplot(223)
ax3 = sns.pointplot(x='Time', y='NumofSpent', hue='Type', data=plot_jul)
ax3.set_title('7월 TOP10 업종 시간대별 총 이용건수')

ax4 = fig.add_subplot(224)
ax4 = sns.pointplot(x='Time', y='NumofSpent', hue='Type', data=plot_aug)
ax4.set_title('8월 TOP10 업종 시간대별 총 이용건수')
plt.show()

# %%
# col = ['NumofSpent', 'NumofDisSpent']
# num2_hanlim = hanlim[col] / hanlim[col].max()

# norm2_hanlim = hanlim.copy()
# norm2_hanlim[col] = num2_hanlim[col]
# norm2_hanlim.tail()

# %%
# time_may_cat = norm2_hanlim[norm2_hanlim['YM'] == 202005].groupby(['Type', 'Time'], as_index=False).sum()
# may_cat = norm2_hanlim[norm2_hanlim['YM'] == 202005].groupby(['Type'], as_index=False).sum()
# may_cat = may_cat.sort_values(by='NumofSpent', ascending=False).head(10)
# may_cat = [i for i in may_cat['Type']]
# plot_may = time_may_cat[time_may_cat['Type'].isin((may_cat))]

# time_jun_cat = norm2_hanlim[norm2_hanlim['YM'] == 202006].groupby(['Type', 'Time'], as_index=False).sum()
# jun_cat = norm2_hanlim[norm2_hanlim['YM'] == 202006].groupby(['Type'], as_index=False).sum()
# jun_cat = jun_cat.sort_values(by='NumofSpent', ascending=False).head(10)
# jun_cat = [i for i in jun_cat['Type']]
# plot_jun = time_jun_cat[time_jun_cat['Type'].isin((jun_cat))]

# time_jul_cat = norm2_hanlim[norm2_hanlim['YM'] == 202007].groupby(['Type', 'Time'], as_index=False).sum()
# jul_cat = norm2_hanlim[norm2_hanlim['YM'] == 202007].groupby(['Type'], as_index=False).sum()
# jul_cat = jul_cat.sort_values(by='NumofSpent', ascending=False).head(10)
# jul_cat = [i for i in jul_cat['Type']]
# plot_jul = time_jul_cat[time_jul_cat['Type'].isin((jul_cat))]

# time_aug_cat = norm2_hanlim[norm2_hanlim['YM'] == 202008].groupby(['Type', 'Time'], as_index=False).sum()
# aug_cat = norm2_hanlim[norm2_hanlim['YM'] == 202008].groupby(['Type'], as_index=False).sum()
# aug_cat = aug_cat.sort_values(by='NumofSpent', ascending=False).head(10)
# aug_cat = [i for i in aug_cat['Type']]
# plot_aug = time_aug_cat[time_aug_cat['Type'].isin((aug_cat))]

# %%
# fig = plt.figure(figsize=(20,20))
# ax1 = fig.add_subplot(221)
# ax1 = sns.pointplot(x='Time', y='NumofSpent', hue='Type', data=plot_may)
# ax1.set_title('5월 TOP10 업종 시간대별 총 이용건수')

# ax2 = fig.add_subplot(222)
# ax2 = sns.pointplot(x='Time', y='NumofSpent', hue='Type', data=plot_jun)
# ax2.set_title('6월 TOP10 업종 시간대별 총 이용건수')

# ax3 = fig.add_subplot(223)
# ax3 = sns.pointplot(x='Time', y='NumofSpent', hue='Type', data=plot_jul)
# ax3.set_title('7월 TOP10 업종 시간대별 총 이용건수')

# ax4 = fig.add_subplot(224)
# ax4 = sns.pointplot(x='Time', y='NumofSpent', hue='Type', data=plot_aug)
# ax4.set_title('8월 TOP10 업종 시간대별 총 이용건수')
# plt.show()

# %%
tim_hanlim = hanlim.groupby(['YM', 'Type', 'Time'], as_index=False).sum()
tim_hanlim['Type'].unique()
# Out:
# array(['건설/제조', '교육/육아', '교통/통신', '농업', '레저/스포츠', '마트/편의점(유통)', '뷰티',
#        '생활/기타', '서비스/기타', '서점/문구', '쇼핑/패션', '여행/숙박', '영화/문화', '외식/주점',
#        '의료', '주유/자동차', '카페/베이커리'], dtype=object)

# %%
## '먹거리'라고 생각되는 Type 따로 불러와서 시간대별 추이 보기

# %%
fig = plt.figure(figsize=(16,12))

ax1 = fig.add_subplot(2, 2, 1)
ax1 = sns.pointplot(x='Time', y='NumofSpent', data=tim_hanlim[(tim_hanlim['Type'] == '외식/주점')].groupby(['Type', 'Time'], as_index=False)['NumofSpent'].sum())
ax1.set_title('외식/주점')
ax2 = fig.add_subplot(2, 2, 2)
ax2 = sns.pointplot(x='Time', y='NumofSpent', data=tim_hanlim[(tim_hanlim['Type'] == '카페/베이커리')].groupby(['Type', 'Time'], as_index=False)['NumofSpent'].sum())
ax2.set_title('카페/베이커리')
ax3 = fig.add_subplot(2, 2, 3)
ax3 = sns.pointplot(x='Time', y='NumofSpent', data=tim_hanlim[(tim_hanlim['Type'] == '마트/편의점(유통)')].groupby(['Type', 'Time'], as_index=False)['NumofSpent'].sum())
ax3.set_title('마트/편의점(유통)')
plt.show()

# %% [markdown]
# ### folium

# %%
hanlim.tail()
# Out:
#         OBJECTID  Field1      YM     SIDO SIGUNGU FranClass   Type Time  \
# 279989    242126  242126  202008  제주특별자치도     제주시        일반   일반한식  21시
# 279990    253957  253957  202008  제주특별자치도     제주시        일반   일반한식  22시
# 279991    262896  262896  202008  제주특별자치도     제주시        일반   일반한식  23시
# 280067    269676  269676  202008  제주특별자치도     제주시        영세  예체능학원   x시
# 280068    270027  270027  202008  제주특별자치도     제주시        영세   기타교육   x시
#
#         TotalSpent  DisSpent  NumofSpent  NumofDisSpent      POINT_X  \
# 279989       12000         0           1              0  886282.6314
# 279990       40000         0           3              0  886282.6314
# 279991       20000         0           1              0  886282.6314
# 280067       44000         0           1              0  884694.4071
# 280068      240000         0           1              0  887877.0846
#
#              POINT_Y                 lon                lat  \
# ...

# %%
# 외식/주점
wesik = hanlim[hanlim['Type'] == '외식/주점']
wesik = wesik[['SIGUNGU','FranClass','Type','lon','lat','lon_lat']]
wesik.drop_duplicates(inplace=True)

# 마트/편의점(유통)
mart = hanlim[hanlim['Type'] == '마트/편의점(유통)']
mart = mart[['SIGUNGU','FranClass','Type','lon','lat','lon_lat']]
mart.drop_duplicates(inplace=True)

# 의료
hos = hanlim[hanlim['Type'] == '의료']
hos = hos[['SIGUNGU','FranClass','Type','lon','lat','lon_lat']]
hos.drop_duplicates(inplace=True)

# 주유/자동차
car = hanlim[hanlim['Type'] == '주유/자동차']
car = car[['SIGUNGU','FranClass','Type','lon','lat','lon_lat']]
car.drop_duplicates(inplace=True)

# %%
import folium
from folium.plugins import MarkerCluster, MiniMap

# %%
map = folium.Map((33.43353201264066, 126.27669458207966), zoom_start=13)
mc = MarkerCluster()

mc.add_child(folium.Marker(location=[33.43353201264066, 126.27669458207966], icon=folium.Icon(color='red')))
minimap = MiniMap()
map.add_child(minimap)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map = folium.Map((33.43353201264066, 126.27669458207966), zoom_start= 13)

# 외식/주점 
for i in range(len(wesik['Type'])):
    folium.Circle(list(wesik.iloc[i][['lat','lon']]), radius=5, color='crimson', fill_color='crimson').add_to(map)
    
# 마트/편의점(유통) 
for i in range(len(mart['Type'])):
    folium.Circle(list(mart.iloc[i][['lat','lon']]), radius=5, color='orange', fill_color='orange').add_to(map)
    
# 의료 
for i in range(len(hos['Type'])):
    folium.Circle(list(hos.iloc[i][['lat','lon']]), radius=5, color='green', fill_color='green').add_to(map)

# 주유/자동차
for i in range(len(car['Type'])):
    folium.Circle(list(car.iloc[i][['lat','lon']]), radius=5, color='gray', fill_color='gray').add_to(map)
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
