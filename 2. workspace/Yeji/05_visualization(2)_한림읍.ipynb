# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

from matplotlib import font_manager
f_path = "C:\Windows\Fonts\malgun.ttf"
font_manager.FontProperties(fname=f_path).get_name()
from matplotlib import rc
rc('font', family='Malgun Gothic')

# %%
df = pd.read_csv('./datas/df3.csv')
df.drop(columns=['Unnamed: 0'], inplace=True)
df
# Out:
#          OBJECTID      YM SIGUNGU FranClass      Type Time  TotalSpent  \
# 0          164793  202006    서귀포시        중소     침구수예점   16       18000
# 1          104496  202006     제주시       중소1      일반한식   13        3800
# 2          236750  202005     제주시        영세       독서실   20       15000
# 3           79865  202005    서귀포시        일반      헬스크럽   12      100000
# 4          202431  202006     제주시       중소2  자동차시트타이어   18       42000
# ...           ...     ...     ...       ...       ...  ...         ...
# 1119424    157537  202005     제주시        일반        신발   16       10100
# 1119425    177587  202005     제주시        영세     스포츠의류   17       38900
# 1119426    115025  202006     제주시       중소1     자동차정비   14       20000
# 1119427    193152  202006    서귀포시        영세      슈퍼마켓   18        9150
# 1119428    138276  202006    서귀포시       중소1     자동차정비   15       52550
#
#          DisSpent  NumofSpent  NumofDisSpent         lon        lat  \
# ...

# %% [markdown]
# ### 한림읍

# %%
hanlim = df[df['dong'].isin(['한림읍'])]
hanlim
# Out:
#          OBJECTID      YM SIGUNGU FranClass     Type Time  TotalSpent  \
# 79           8586  202005     제주시        영세     일반한식    2       53000
# 411          8580  202005     제주시       중소1      편의점    2        5400
# 561         30767  202005     제주시        영세     일반한식    9        1000
# 563         41446  202005     제주시        영세     일반한식   10       20000
# 567        112081  202005     제주시        영세     일반한식   14       15500
# ...           ...     ...     ...       ...      ...  ...         ...
# 1119300    172943  202008     제주시        중소  스포츠레져용품   17       40000
# 1119303    133844  202008     제주시        중소  스포츠레져용품   15      130000
# 1119307    153515  202008     제주시        중소  스포츠레져용품   16      131000
# 1119395     31366  202005     제주시       중소1     기타잡화   09      213500
# 1119410     56056  202005     제주시        영세       안경   11      300000
#
#          DisSpent  NumofSpent  NumofDisSpent         lon        lat  \
# ...

# %%
hanlim_type = hanlim.groupby(['YM', 'Type']).mean()
hanlim_type.reset_index(inplace=True)
hanlim_type[hanlim_type['YM'] == 202005].sort_values(by='dis/tot', ascending=False).head(10)
# Out:
#          YM      Type       OBJECTID     TotalSpent       DisSpent  \
# 81   202005      인삼제품  112730.750000   80750.000000   68750.000000
# 75   202005      유류판매  100985.583333  728583.333333  298416.666667
# 54   202005  사무통신기기수리  162589.000000   68500.000000   15000.000000
# 109  202005     캐쥬얼의류  122745.500000   58500.000000    6000.000000
# 69   202005        안경  115046.590909  301363.636364  125045.454545
# 73   202005     예체능학원  150529.608696  214130.434783   93304.347826
# 13   202005     기타건강식   86891.000000   99941.176471   36764.705882
# 24   202005     기타유통업   93178.666667  905520.000000  193870.000000
# 30   202005     내의판매점  140781.714286  139500.000000   69000.000000
# 46   202005       미곡상   98898.000000  500750.000000   76000.000000
#
#      NumofSpent  NumofDisSpent         lon        lat   dis/tot  count
# 81     1.500000       1.250000  126.264136  33.416228  0.925000    1.0
# 75     3.416667       1.333333  126.272009  33.419042  0.516667    1.0
# ...

# %%
col = ['NumofSpent', 'NumofDisSpent']
num_hanlim_5 = (hanlim_type[hanlim_type['YM'] == 202005][col]) / (hanlim_type[hanlim_type['YM'] == 202005][col].max())
num_hanlim_6 = (hanlim_type[hanlim_type['YM'] == 202006][col]) / (hanlim_type[hanlim_type['YM'] == 202006][col].max())
num_hanlim_7 = (hanlim_type[hanlim_type['YM'] == 202007][col]) / (hanlim_type[hanlim_type['YM'] == 202007][col].max())
num_hanlim_8 = (hanlim_type[hanlim_type['YM'] == 202008][col]) / (hanlim_type[hanlim_type['YM'] == 202008][col].max())

# %%
norm_hanlim_5 = hanlim_type[hanlim_type['YM'] == 202005].copy()
norm_hanlim_6 = hanlim_type[hanlim_type['YM'] == 202006].copy()
norm_hanlim_7 = hanlim_type[hanlim_type['YM'] == 202007].copy()
norm_hanlim_8 = hanlim_type[hanlim_type['YM'] == 202008].copy()

norm_hanlim_5[col] = num_hanlim_5[col]
norm_hanlim_6[col] = num_hanlim_6[col]
norm_hanlim_7[col] = num_hanlim_7[col]
norm_hanlim_8[col] = num_hanlim_8[col]

# %%
norm_hanlim_5.nlargest(10, 'dis/tot')
# Out:
#          YM      Type       OBJECTID     TotalSpent       DisSpent  \
# 81   202005      인삼제품  112730.750000   80750.000000   68750.000000
# 75   202005      유류판매  100985.583333  728583.333333  298416.666667
# 54   202005  사무통신기기수리  162589.000000   68500.000000   15000.000000
# 109  202005     캐쥬얼의류  122745.500000   58500.000000    6000.000000
# 69   202005        안경  115046.590909  301363.636364  125045.454545
# 73   202005     예체능학원  150529.608696  214130.434783   93304.347826
# 13   202005     기타건강식   86891.000000   99941.176471   36764.705882
# 24   202005     기타유통업   93178.666667  905520.000000  193870.000000
# 30   202005     내의판매점  140781.714286  139500.000000   69000.000000
# 46   202005       미곡상   98898.000000  500750.000000   76000.000000
#
#      NumofSpent  NumofDisSpent         lon        lat   dis/tot  count
# 81     0.002294       0.008873  126.264136  33.416228  0.925000    1.0
# 75     0.005225       0.009464  126.272009  33.419042  0.516667    1.0
# ...

# %%
fig = plt.figure(figsize=(16, 10))
ax1 = fig.add_subplot(1, 2, 1)
ax1 = sns.set_color_codes('muted')
ax1 = sns.barplot(x='Type', y='NumofDisSpent', data=norm_hanlim_5.nlargest(10, 'dis/tot'), color='b')
ax1.set_title('5월 업종별 평균 재난지원금 이용건수')
plt.setp(ax1.get_xticklabels(), rotation=45)
ax1.set(ylim=(0.0, 0.020))
ax2 = fig.add_subplot(1, 2, 2)
ax2 = sns.set_color_codes('pastel')
ax2 = sns.barplot(x='Type', y='NumofSpent', data=norm_hanlim_5.nlargest(10, 'dis/tot'), color='b')
ax2.set_title('5월 업종별 평균 이용건수')
plt.setp(ax2.get_xticklabels(), rotation=45)
ax2.set(ylim=(0.0, 0.020))
plt.show()

# %%
norm_hanlim_6.nlargest(10, 'dis/tot')
# Out:
#          YM      Type       OBJECTID     TotalSpent      DisSpent  NumofSpent  \
# 230  202006     캐쥬얼의류   81577.500000   24000.000000  24000.000000    0.002315
# 152  202006     내의판매점  155357.600000   82800.000000  34294.000000    0.003087
# 224  202006      치과병원  127666.800000    9980.000000   1980.000000    0.001852
# 200  202006      의료용품  115464.250000   81833.333333   9416.666667    0.002830
# 145  202006   기타용역서비스   94046.750000  114958.333333  26870.833333    0.002058
# 172  202006      보습학원  202693.392857  364714.285714  58790.357143    0.002425
# 135  202006     기타건강식  101998.307692  104230.769231  20000.000000    0.002256
# 173  202006     보일러펌프  103405.040000  207428.000000  12289.200000    0.007100
# 168  202006       미곡상   99321.666667  241416.666667  18791.666667    0.001929
# 174  202006  비료농약사료종자  100422.683544  798385.455696  60950.949367    0.008831
#
#      NumofDisSpent         lon        lat   dis/tot  count
# ...

# %%
fig = plt.figure(figsize=(16, 10))
ax1 = fig.add_subplot(1, 2, 1)
ax1 = sns.set_color_codes('muted')
ax1 = sns.barplot(x='Type', y='NumofDisSpent', data=norm_hanlim_6.nlargest(10, 'dis/tot'), color='b')
plt.setp(ax1.get_xticklabels(), rotation=45)
ax1.set(ylim=(0.0, 0.020))
ax2 = fig.add_subplot(1, 2, 2)
ax2 = sns.set_color_codes('pastel')
ax2 = sns.barplot(x='Type', y='NumofSpent', data=norm_hanlim_6.nlargest(10, 'dis/tot'), color='b')
plt.setp(ax2.get_xticklabels(), rotation=45)
ax2.set(ylim=(0.0, 0.020))
plt.show()

# %%
norm_hanlim_7.nlargest(10, 'dis/tot')
# Out:
#          YM       Type       OBJECTID     TotalSpent      DisSpent  \
# 353  202007      캐쥬얼의류   24576.000000    6000.000000   6000.000000
# 340  202007       주방용구  109453.428571   69171.428571  32571.428571
# 319  202007       유류판매  138540.500000  183625.000000  18250.000000
# 273  202007  기타회원제형태업소  100422.800000   49300.000000   2150.000000
# 365  202007       화물운송  118463.400000  148050.000000   1750.000000
# 367  202007        화장품  121907.096154  213423.076923   7918.269231
# 334  202007        정육점  133612.509434  498554.716981   7442.547170
# 296  202007   비료농약사료종자  103463.690476  881631.285714  10454.642857
# 362  202007        한의원  108149.428571   89628.571429   1945.357143
# 303  202007        세탁소  133971.888889   64222.222222   1861.111111
#
#      NumofSpent  NumofDisSpent         lon        lat   dis/tot  count
# 353    0.001520       0.068548  126.273728  33.420418  1.000000    1.0
# 340    0.002824       0.009793  126.240385  33.398505  0.142857    1.0
# ...

# %%
fig = plt.figure(figsize=(16, 10))
ax1 = fig.add_subplot(1, 2, 1)
ax1 = sns.set_color_codes('muted')
ax1 = sns.barplot(x='Type', y='NumofDisSpent', data=norm_hanlim_7.nlargest(10, 'dis/tot'), color='b')
plt.setp(ax1.get_xticklabels(), rotation=45)
ax1.set(ylim=(0.0, 0.050))
ax2 = fig.add_subplot(1, 2, 2)
ax2 = sns.set_color_codes('pastel')
ax2 = sns.barplot(x='Type', y='NumofSpent', data=norm_hanlim_7.nlargest(10, 'dis/tot'), color='b')
plt.setp(ax2.get_xticklabels(), rotation=45)
ax2.set(ylim=(0.0, 0.050))
plt.show()

# %%
norm_hanlim_8.nlargest(10, 'dis/tot')
# Out:
#          YM       Type       OBJECTID     TotalSpent      DisSpent  \
# 413  202008        미곡상  124067.866667  162366.666667   7333.333333
# 446  202008       의료용품  116017.666667   68666.666667   4583.333333
# 411  202008       문구용품  117597.363636  153141.212121   2788.484848
# 472  202008       치과의원  108637.756098  565904.146341   1297.560976
# 433  202008         신발  124713.952381  102647.142857   1190.476190
# 458  202008        정육점  126919.295918  633944.795918   5959.591837
# 402  202008      농축수산품  124053.606232  352580.807365   1847.365439
# 455  202008      자동차부품  101454.058824  382058.823529  12979.411765
# 419  202008   비료농약사료종자   92521.455696  625866.746835   8370.886076
# 397  202008  기타회원제형태업소  102448.111111  108555.555556   3333.333333
#
#      NumofSpent  NumofDisSpent         lon        lat   dis/tot  count
# 413    0.002202       0.010494  126.268027  33.409700  0.066667    1.0
# 446    0.002633       0.013117  126.264931  33.412257  0.041667    1.0
# ...

# %%
fig = plt.figure(figsize=(16, 10))
ax1 = fig.add_subplot(1, 2, 1)
ax1 = sns.set_color_codes('muted')
ax1 = sns.barplot(x='Type', y='NumofDisSpent', data=norm_hanlim_8.nlargest(10, 'dis/tot'), color='b')
plt.setp(ax1.get_xticklabels(), rotation=45)
ax1.set(ylim=(0.0, 0.030))
ax2 = fig.add_subplot(1, 2, 2)
ax2 = sns.set_color_codes('pastel')
ax2 = sns.barplot(x='Type', y='NumofSpent', data=norm_hanlim_8.nlargest(10, 'dis/tot'), color='b')
plt.setp(ax2.get_xticklabels(), rotation=45)
ax2.set(ylim=(0.0, 0.030))
plt.show()

# %%
hanlim_class = hanlim.groupby(['YM', 'FranClass', 'Type'], as_index=False).mean()
hanlim_class[hanlim_class['FranClass'] == '중소'].nlargest(10, 'dis/tot')
# Out:
#          YM FranClass   Type       OBJECTID     TotalSpent       DisSpent  \
# 171  202005        중소   인삼제품  112730.750000   80750.000000   68750.000000
# 177  202005        중소    주유소   95514.600000  353800.000000  236400.000000
# 179  202005        중소   치과의원   90750.500000  358037.500000   90043.750000
# 175  202005        중소    정육점  147698.500000  169666.666667   24611.111111
# 150  202005        중소    LPG  106549.640000  130200.000000   40760.000000
# 168  202005        중소     약국  105161.545455  405764.545455  137898.181818
# 153  202005        중소   기계공구   92703.333333   57333.333333   23333.333333
# 157  202005        중소  농축수산품   85400.260870  463304.347826   97043.478261
# 176  202005        중소  주방용식기  107360.333333  548183.333333  136416.666667
# 174  202005        중소  자동차부품   91818.916667  566750.000000  113750.000000
#
#      NumofSpent  NumofDisSpent         lon        lat   dis/tot  count
# 171    1.500000       1.250000  126.264136  33.416228  0.925000    1.0
# ...

# %%
hanlim_class = hanlim.groupby(['YM', 'FranClass'], as_index=False).mean()
hanlim_class.tail()
# Out:
#         YM FranClass       OBJECTID    TotalSpent     DisSpent  NumofSpent  \
# 15  202008        영세  132728.319941  2.654800e+05   502.026588    9.536041
# 16  202008        일반  124524.560465  2.354833e+06  8977.095349   42.201163
# 17  202008        중소  130325.540777  4.926658e+05  1369.543689   18.580583
# 18  202008       중소1  123177.040397  7.966343e+05  1858.690999   34.750532
# 19  202008       중소2  113801.918803  1.119169e+06  4178.119658   43.153846
#
#     NumofDisSpent         lon        lat   dis/tot  count
# 15       0.026292  126.260265  33.406851  0.002644    1.0
# 16       0.206977  126.268306  33.398644  0.002442    1.0
# 17       0.051456  126.263614  33.405647  0.003786    1.0
# 18       0.085046  126.258973  33.405787  0.002977    1.0
# 19       0.160256  126.266359  33.405906  0.003419    1.0

# %%
plt.figure(figsize=(10,8))
sns.barplot(x='YM', y='dis/tot', hue='FranClass', data=hanlim_class, palette='coolwarm');

# %%
fig = plt.figure(figsize=(20,20))
ax1 = fig.add_subplot(411)
ax1 = sns.barplot(x='Type', y='NumofSpent', data=norm_hanlim_5.nlargest(10, 'NumofSpent'), palette='coolwarm')
# ax1.set_xticks(fontsize=10, rotation=45)
ax1.set_title('5월 업종별 평균 이용건수 (NumofSpent)')

ax2 = fig.add_subplot(412)
ax2 = sns.barplot(x='Type', y='NumofSpent', data=norm_hanlim_6.nlargest(10, 'NumofSpent'), palette='coolwarm')
# ax2.set_xticks(fontsize=10, rotation=45)
ax2.set_title('6월 업종별 평균 이용건수 (NumofSpent)')

ax3 = fig.add_subplot(413)
ax3 = sns.barplot(x='Type', y='NumofSpent', data=norm_hanlim_7.nlargest(10, 'NumofSpent'), palette='coolwarm')
# ax3.set_xticks(fontsize=10, rotation=45)
ax3.set_title('7월 업종별 평균 이용건수 (NumofSpent)')

ax4 = fig.add_subplot(414)
ax4 = sns.barplot(x='Type', y='NumofSpent', data=norm_hanlim_8.nlargest(10, 'NumofSpent'), palette='coolwarm')
# ax1.set_xticks(fontsize=10, rotation=45)
ax4.set_title('8월 업종별 평균 이용건수 (NumofSpent)')
plt.show()

# %%
fig = plt.figure(figsize=(20,20))
ax1 = fig.add_subplot(411)
ax1 = sns.barplot(x='Type', y='NumofDisSpent', data=norm_hanlim_5.nlargest(10, 'NumofDisSpent'), palette='coolwarm')
# ax1.set_xticks(fontsize=10, rotation=45)
ax1.set_title('5월 업종별 평균 지원금 이용건수 (NumofDisSpent)')

ax2 = fig.add_subplot(412)
ax2 = sns.barplot(x='Type', y='NumofDisSpent', data=norm_hanlim_6.nlargest(10, 'NumofDisSpent'), palette='coolwarm')
# ax2.set_xticks(fontsize=10, rotation=45)
ax2.set_title('6월 업종별 평균 지원금 이용건수 (NumofDisSpent)')

ax3 = fig.add_subplot(413)
ax3 = sns.barplot(x='Type', y='NumofDisSpent', data=norm_hanlim_7.nlargest(10, 'NumofDisSpent'), palette='coolwarm')
# ax3.set_xticks(fontsize=10, rotation=45)
ax3.set_title('7월 업종별 평균 지원금 이용건수 (NumofDisSpent)')

ax4 = fig.add_subplot(414)
ax4 = sns.barplot(x='Type', y='NumofDisSpent', data=norm_hanlim_8.nlargest(10, 'NumofDisSpent'), palette='coolwarm')
# ax1.set_xticks(fontsize=10, rotation=45)
ax4.set_title('8월 업종별 평균 지원금 이용건수 (NumofDisSpent)')
plt.show()

# %%
import folium
from folium.plugins import MarkerCluster, MiniMap

# %%
map = folium.Map((33.447843033444606, 126.30114679770172), zoom_start=13)
mc = MarkerCluster()

mc.add_child(folium.Marker(location=[33.447843033444606, 126.30114679770172], popup='중소2', icon=folium.Icon(color='red')))
minimap = MiniMap()
map.add_child(minimap)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 농축협직영매장
nonghyop = hanlim[hanlim['Type'] == '농축협직영매장']
nonghyop = nonghyop[['SIGUNGU','FranClass','Type','lon','lat','lon_lat']]
nonghyop.drop_duplicates(inplace=True)

# 골프경기장
golf = hanlim[hanlim['Type'] == '골프경기장']
golf = golf[['SIGUNGU','FranClass','Type','lon','lat','lon_lat']]
golf.drop_duplicates(inplace=True)

# 슈퍼마켓
mart = hanlim[hanlim['Type'] == '슈퍼마켓']
mart = mart[['SIGUNGU','FranClass','Type','lon','lat','lon_lat']]
mart.drop_duplicates(inplace=True)

# 비료농약사료종자
biryo = hanlim[hanlim['Type'] == '비료농약사료종자']
biryo = biryo[['SIGUNGU','FranClass','Type','lon','lat','lon_lat']]
biryo.drop_duplicates(inplace=True)

# 주유소
gas = hanlim[hanlim['Type'] == '주유소']
gas = gas[['SIGUNGU','FranClass','Type','lon','lat','lon_lat']]
gas.drop_duplicates(inplace=True)

# %%
map = folium.Map((33.447843033444606, 126.30114679770172), zoom_start= 13)

# 농축협직영매장
for i in range(len(nonghyop['Type'])):
    folium.Circle(list(nonghyop.iloc[i][['lat','lon']]), radius=100, color='crimson', fill_color='crimson').add_to(map)
    
# 골프경기장 
for i in range(len(golf['Type'])):
    folium.Circle(list(golf.iloc[i][['lat','lon']]), radius=100, color='orange', fill_color='orange').add_to(map)
    
# 슈퍼마켓 
for i in range(len(mart['Type'])):
    folium.Circle(list(mart.iloc[i][['lat','lon']]), radius=100, color='green', fill_color='green').add_to(map)

# 비료농약사료종자 
for i in range(len(biryo['Type'])):
    folium.Circle(list(biryo.iloc[i][['lat','lon']]), radius=100, color='gray', fill_color='gray').add_to(map)
    
# 주유소 
for i in range(len(gas['Type'])):
    folium.Circle(list(gas.iloc[i][['lat','lon']]), radius=100, color='black', fill_color='gray').add_to(map)
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
